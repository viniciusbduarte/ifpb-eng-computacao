# %% [markdown]
# # Lista de Exercícios 1.2 - Estimação de π por aproximação por série de Taylor

# %% [markdown]
# Aluno: Vinicius Batista Duarte

# %%
import numpy as np

# %% [markdown]
# pi_k = 4 * sum((-1)^n / (2n + 1))

# %%
# Valor real de pi usando numpy
pi_real = np.pi

# %%
# Testando para alguns valores de k
valores_k = [1, 2, 3, 10, 100, 1000]

# %%
for k in valores_k:
    pi_estimado = estima_pi(k)

    erro = np.abs(pi_real - pi_estimado)

    print(f"k = {k}")
    print(f"pi aproximado = {pi_estimado}")
    print(f"Erro absoluto = {erro}")
    print("-" * 40)
# Out:
# k = 1
# pi aproximado = 4.0
# Erro absoluto = 0.8584073464102069
# ----------------------------------------
# k = 2
# pi aproximado = 2.666666666666667
# Erro absoluto = 0.47492598692312615
# ----------------------------------------
# k = 3
# pi aproximado = 3.466666666666667
# Erro absoluto = 0.32507401307687367
# ----------------------------------------
# k = 10
# pi aproximado = 3.0418396189294024
# Erro absoluto = 0.09975303466039076
# ----------------------------------------
# k = 100
# pi aproximado = 3.131592903558552
# Erro absoluto = 0.009999750031241206
# ----------------------------------------
# k = 1000
# pi aproximado = 3.140592653839792
# Erro absoluto = 0.0009999997500012014
# ----------------------------------------

# %%
import matplotlib.pyplot as plt

# %%
k_values = np.arange(1, 1000)

# %%
erros = []

# %%
for k in k_values:
    pi_estimado = estima_pi(k)
    erro = np.abs(np.pi - pi_estimado)
    erros.append(erro)

# %%
plt.figure(figsize=(8,5))

plt.plot(k_values, erros)

plt.xlabel("Número de termos (k)")
plt.ylabel("Erro absoluto")
plt.title("Erro da aproximação de pi pela série de Taylor")

plt.grid()

plt.show()
